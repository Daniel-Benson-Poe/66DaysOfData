# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-Benson-Poe/66DaysOfData/blob/main/DataVisualizationKaggleMiniCourse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Hello, Seaborn

# %%
#Setup notebook
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup complete")
# Out:
# Setup complete

# %%
url = "https://storage.googleapis.com/kagglesdsdata/datasets/116573/3551030/fifa.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220728%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220728T194608Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

# %%
#load data
fifa_data = pd.read_csv(url, index_col="Date", parse_dates=True)

# %%
# Examine the data
fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
#Plot the data

#Set width and height of figure
plt.figure(figsize=(16,6))

#Line chart showing FIFA ranking evolution over time
sns.lineplot(data=fifa_data)

# %% [markdown]
# ##Your Turn

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa_data)

# %% [markdown]
# #Line Charts

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
#URL where raw data is located
url = "https://storage.googleapis.com/kagglesdsdata/datasets/116573/334386/spotify.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220728%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220728T195304Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

# %%
#Read data
spotify_data = pd.read_csv(url, index_col="Date", parse_dates=True)

# %%
#Examine the data
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
#Examine last five rows of data
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
#Plot the data!
sns.lineplot(data=spotify_data)

# %%
#Set width and height of figure
plt.figure(figsize=(14,6))

#Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

#Line chart showing daily global streams of each song
sns.lineplot(data=spotify_data)

# %%
# Check subset of data
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %%
#Set width and height
plt.figure(figsize=(14, 6))

#Add title
plt.title("Daily Global Streams of Popular Songs in 2017 = 2018")

#Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

#Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify_data['Despacito'], label="Despacity")

#Add label for horizontal axis
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ##Your Turn

# %%
url = "https://storage.googleapis.com/kagglesdsdata/datasets/116573/334386/museum_visitors.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220728%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220728T200057Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

# %%
#Load in the data
museum_data = pd.read_csv(url, index_col="Date", parse_dates=True)

# %% [markdown]
# Use a Python command to print the last 5 rows of the data.

# %%
museum_data.tail()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2018-07-01        23136              4191                     2620
# 2018-08-01        20815              4866                     2409
# 2018-09-01        21020              4956                     2146
# 2018-10-01        19280              4622                     2364
# 2018-11-01        17163              4082                     2385
#
#             America Tropical Interpretive Center
# Date
# 2018-07-01                                  4718
# 2018-08-01                                  3891
# 2018-09-01                                  3180
# 2018-10-01                                  3775
# 2018-11-01                                  4562

# %%
# Fill in the line below: How many visitors did the Chinese American Museum 
# receive in July 2018?
ca_museum_jul18 = 2620 

# Fill in the line below: In October 2018, how many more visitors did Avila 
# Adobe receive than the Firehouse Museum?
avila_oct18 = 19280 - 4622

# %%
#Line chart showing number of visitors to each museum over time
sns.lineplot(data=museum_data)

# %% [markdown]
# Create a line chart that shows how the number of visitors to Avila Adobe has evolved over time. (If your code returns an error, the first thing that you should check is that you've spelled the name of the column correctly! You must write the name of the column exactly as it appears in the dataset.)

# %%
#Line plot showing number of visitors to Avila Adobe over time
sns.lineplot(data=museum_data["Avila Adobe"])
